# %%
# install dependencies
# !pip install tensorflow==2.3.0
# !pip install keras==2.4.3
# !pip install gym==0.17.3
# !pip install keras-rl2==1.0.4

# %%
from typing import Optional
import numpy as np
import gymnasium as gym


class GridWorldEnv(gym.Env):

    def __init__(self, size: int = 5):
        # The size of the square grid (5x5 by default)
        self.size = size

        # Initialize positions - will be set randomly in reset()
        # Using -1,-1 as "uninitialized" state
        self._agent_location = np.array([-1, -1], dtype=np.int32)
        self._target_location = np.array([-1, -1], dtype=np.int32)

        # Define what the agent can observe
        # Dict space gives us structured, human-readable observations
        self.observation_space = gym.spaces.Dict(
            {
                "agent": gym.spaces.Box(0, size - 1, shape=(2,), dtype=int),   # [x, y] coordinates
                "target": gym.spaces.Box(0, size - 1, shape=(2,), dtype=int),  # [x, y] coordinates
            }
        )

        # Define what actions are available (4 directions)
        self.action_space = gym.spaces.Discrete(4)

        # Map action numbers to actual movements on the grid
        # This makes the code more readable than using raw numbers
        self._action_to_direction = {
            0: np.array([1, 0]),   # Move right (positive x)
            1: np.array([0, 1]),   # Move up (positive y)
            2: np.array([-1, 0]),  # Move left (negative x)
            3: np.array([0, -1]),  # Move down (negative y)
        }
    
    def _get_obs(self):
        """Convert internal state to observation format.
    
        Returns:
            dict: Observation with agent and target positions
        """
        return {"agent": self._agent_location, "target": self._target_location}
    
    def _get_info(self):
        """Compute auxiliary information for debugging.

        Returns:
            dict: Info with distance between agent and target
        """
        return {
            "distance": np.linalg.norm(
                self._agent_location - self._target_location, ord=1
            )
        }

    def reset(self, seed: Optional[int] = None, options: Optional[dict] = None):
        """Start a new episode.

        Args:
            seed: Random seed for reproducible episodes
            options: Additional configuration (unused in this example)

        Returns:
            tuple: (observation, info) for the initial state
        """
        # IMPORTANT: Must call this first to seed the random number generator
        super().reset(seed=seed)

        # Randomly place the agent anywhere on the grid
        self._agent_location = self.np_random.integers(0, self.size, size=2, dtype=int)

        # Randomly place target, ensuring it's different from agent position
        self._target_location = self._agent_location
        while np.array_equal(self._target_location, self._agent_location):
            self._target_location = self.np_random.integers(
                0, self.size, size=2, dtype=int
            )

        observation = self._get_obs()
        info = self._get_info()

        return observation, info

    def step(self, action):
        """Execute one timestep within the environment.

        Args:
            action: The action to take (0-3 for directions)

        Returns:
            tuple: (observation, reward, terminated, truncated, info)
        """
        # Map the discrete action (0-3) to a movement direction
        direction = self._action_to_direction[action]

        # Update agent position, ensuring it stays within grid bounds
        # np.clip prevents the agent from walking off the edge
        self._agent_location = np.clip(
            self._agent_location + direction, 0, self.size - 1
        )

        # Check if agent reached the target
        terminated = np.array_equal(self._agent_location, self._target_location)

        # We don't use truncation in this simple environment
        # (could add a step limit here if desired)
        truncated = False

        # Simple reward structure: +1 for reaching target, 0 otherwise
        # Alternative: could give small negative rewards for each step to encourage efficiency
        reward = 1 if terminated else 0

        observation = self._get_obs()
        info = self._get_info()

        return observation, reward, terminated, truncated, info

# %%
import gym



import random

# %%
from gym import Env
from gym.spaces import Discrete, Box
import numpy as np
import matplotlib.pyplot as plt

class PulsrEnv(Env):
    def __init__(self):
        # Actions: 0=N, 1=E, 2=S, 3=W
        self.action_space = Discrete(4)
        
        # State: [x, y, score]
        self.observation_space = Box(
            low=np.array([-100.0, -100.0, 0.0], dtype=np.float32),
            high=np.array([100.0, 100.0, np.inf], dtype=np.float32),
            dtype=np.float32
        )
        
        # Circle radius for the ball trajectory
        self.radius = 100
        self.max_steps = 239
        
        # Visualization setup
        self.fig, self.ax = None, None
        self.agent_plot, self.ball_plot, self.traj_plot = None, None, None
        self.trajectory = []
        
        self.reset()
    
    def step(self, action):
        old_x, old_y, _ = self.state
        
        # --- Apply action ---
        if action == 0:   # North
            self.state[1] += 1
        elif action == 1: # East
            self.state[0] += 1
        elif action == 2: # South
            self.state[1] -= 1
        elif action == 3: # West
            self.state[0] -= 1
        
        # --- Keep agent inside workspace ---
        if not (-100 <= self.state[0] <= 100 and -100 <= self.state[1] <= 100):
            self.state[0], self.state[1] = old_x, old_y
        
        # --- Move ball along circular trajectory ---
        angle = (2 * np.pi * self.episode_length) / self.max_steps
        self.ball_pos = np.array([
            self.radius * np.sin(angle),   # x
            self.radius * np.cos(angle)    # y (starts at top)
        ])
        
        # --- Distance & scoring ---
        d = np.linalg.norm(self.state[:2] - self.ball_pos)
        if d <= 70:
            self.state[2] += 1   # increase score
        
        # --- Use score as reward ---
        reward = self.state[2]
        
        # --- Step update ---
        self.episode_length += 1
        done = self.episode_length >= self.max_steps
        
        # --- Final reward mapping ---
        info = {}
        if done:
            score = self.state[2]
            if score > 150:
                info["final_reward"] = 3
            elif 100 <= score <= 150:
                info["final_reward"] = 2
            elif 90 <= score < 100:
                info["final_reward"] = 1
            elif score == 90:
                info["final_reward"] = 0
            elif 70 <= score < 90:
                info["final_reward"] = -1
            elif 50 <= score < 70:
                info["final_reward"] = -2
            else:
                info["final_reward"] = -3
        
        return self.state.copy(), reward, done, info
        
    def reset(self):
        # Reset agent and trajectory
        self.state = np.array([0, 0, 0], dtype=np.float32)
        self.episode_length = 0
        self.trajectory = []
        
        # Start ball at angle=0
        self.ball_pos = np.array([self.radius, 0])
        
        return self.state.copy()
    
    def render(self, mode="human"):
        if self.fig is None:
            plt.ion()
            self.fig, self.ax = plt.subplots(figsize=(6, 6));
            # plt.close(self.fig)   # suppress <Figure ...> in notebook output
            
            self.ax.set_xlim(-120, 120)
            self.ax.set_ylim(-120, 120)
            self.ax.set_aspect("equal")
            self.ax.set_title("PULSR Environment")
            
            circle = plt.Circle((0, 0), self.radius, color="gray", fill=False, linestyle="--")
            self.ax.add_patch(circle)
            
            self.agent_plot, = self.ax.plot([], [], "bo", label="Agent")
            self.ball_plot, = self.ax.plot([], [], "ro", label="Ball")
            self.traj_plot, = self.ax.plot([], [], "b--", linewidth=0.8, alpha=0.6, label="Trajectory")
            
            self.ax.legend()

        # Update agent and ball positions
        self.agent_plot.set_data([self.state[0]], [self.state[1]])
        self.ball_plot.set_data([self.ball_pos[0]], [self.ball_pos[1]])
        
        if len(self.trajectory) > 1:
            traj = np.array(self.trajectory)
            self.traj_plot.set_data(traj[:, 0], traj[:, 1])
        
        plt.draw()
        plt.pause(0.01)

# %%
env = PulsrEnv()

# %%
env.observation_space.sample()
# Out:
# array([  4.1280737, -29.678541 ,   0.5121868], dtype=float32)

# %%
episodes = 10
for episode in range(1, episodes+1):
    state = env.reset()
    done = False
    score = 0 
    
    while not done:
        # env.render()
        action = env.action_space.sample()
        n_state, reward, done, info = env.step(action)
        # print(n_state)
        # score = reward
    print('Episode:{} Score:{} info:{}'.format(episode, reward, info))
# Out:
# Episode:1 Score:0.0 info:{'final_reward': -3}
# Episode:2 Score:0.0 info:{'final_reward': -3}
# Episode:3 Score:0.0 info:{'final_reward': -3}
# Episode:4 Score:0.0 info:{'final_reward': -3}
# Episode:5 Score:0.0 info:{'final_reward': -3}
# Episode:6 Score:0.0 info:{'final_reward': -3}
# Episode:7 Score:0.0 info:{'final_reward': -3}
# Episode:8 Score:0.0 info:{'final_reward': -3}
# Episode:9 Score:0.0 info:{'final_reward': -3}
# Episode:10 Score:0.0 info:{'final_reward': -3}

# %% [markdown]
# ### Create A Deep Learning Model with Keras

# %%
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.optimizers import Adam

# %%
states = env.observation_space.shape
actions = env.action_space.n

# %%
actions
# Out:
# 4

# %%
def build_model(states, actions):
    model = Sequential()    
    model.add(Dense(24, activation='relu', input_shape=states))
    model.add(Dense(24, activation='relu'))
    model.add(Dense(actions, activation='linear'))
    return model

# %%
model = build_model(states, actions)
# Out:
# C:\Users\user\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 24)             │            96 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 24)             │           600 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 4)              │           100 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 796 (3.11 KB)
#  Trainable params: 796 (3.11 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ### Build Agent with Keras-RL

# %%
# from rl.agents import DQNAgent
# from rl.policy import BoltzmannQPolicy
from rl.memory import SequentialMemory

# %%
# !pip install stable-baselines3
# Out:
# Collecting stable-baselines3
#   Downloading stable_baselines3-2.7.0-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: gymnasium<1.3.0,>=0.29.1 in c:\users\user\anaconda3\lib\site-packages (from stable-baselines3) (1.2.0)
# Requirement already satisfied: numpy<3.0,>=1.20 in c:\users\user\anaconda3\lib\site-packages (from stable-baselines3) (2.1.3)
# Requirement already satisfied: torch<3.0,>=2.3 in c:\users\user\anaconda3\lib\site-packages (from stable-baselines3) (2.8.0)
# Requirement already satisfied: cloudpickle in c:\users\user\anaconda3\lib\site-packages (from stable-baselines3) (1.6.0)
# Requirement already satisfied: pandas in c:\users\user\anaconda3\lib\site-packages (from stable-baselines3) (2.2.3)
# Requirement already satisfied: matplotlib in c:\users\user\anaconda3\lib\site-packages (from stable-baselines3) (3.10.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in c:\users\user\anaconda3\lib\site-packages (from gymnasium<1.3.0,>=0.29.1->stable-baselines3) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in c:\users\user\anaconda3\lib\site-packages (from gymnasium<1.3.0,>=0.29.1->stable-baselines3) (0.0.4)
# Requirement already satisfied: filelock in c:\users\user\anaconda3\lib\site-packages (from torch<3.0,>=2.3->stable-baselines3) (3.17.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\user\anaconda3\lib\site-packages (from torch<3.0,>=2.3->stable-baselines3) (1.13.3)
# Requirement already satisfied: networkx in c:\users\user\anaconda3\lib\site-packages (from torch<3.0,>=2.3->stable-baselines3) (3.4.2)
# Requirement already satisfied: jinja2 in c:\users\user\anaconda3\lib\site-packages (from torch<3.0,>=2.3->stable-baselines3) (3.1.6)
# Requirement already satisfied: fsspec in c:\users\user\anaconda3\lib\site-packages (from torch<3.0,>=2.3->stable-baselines3) (2025.3.2)
# Requirement already satisfied: setuptools in c:\users\user\anaconda3\lib\site-packages (from torch<3.0,>=2.3->stable-baselines3) (72.1.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\user\anaconda3\lib\site-packages (from sympy>=1.13.3->torch<3.0,>=2.3->stable-baselines3) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\user\anaconda3\lib\site-packages (from jinja2->torch<3.0,>=2.3->stable-baselines3) (3.0.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\user\anaconda3\lib\site-packages (from matplotlib->stable-baselines3) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\user\anaconda3\lib\site-packages (from matplotlib->stable-baselines3) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\user\anaconda3\lib\site-packages (from matplotlib->stable-baselines3) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\user\anaconda3\lib\site-packages (from matplotlib->stable-baselines3) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\user\anaconda3\lib\site-packages (from matplotlib->stable-baselines3) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\user\anaconda3\lib\site-packages (from matplotlib->stable-baselines3) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\user\anaconda3\lib\site-packages (from matplotlib->stable-baselines3) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\user\anaconda3\lib\site-packages (from matplotlib->stable-baselines3) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\user\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->stable-baselines3) (1.17.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\user\anaconda3\lib\site-packages (from pandas->stable-baselines3) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\user\anaconda3\lib\site-packages (from pandas->stable-baselines3) (2025.2)
# Downloading stable_baselines3-2.7.0-py3-none-any.whl (187 kB)
# Installing collected packages: stable-baselines3
# Successfully installed stable-baselines3-2.7.0

# %%
from stable_baselines3 import DQN
from stable_baselines3.dqn import MlpPolicy

# %%
# Create the DQN agent
model = DQN(
    "MlpPolicy",       # replaces the Keras model + policy
    env,               # your PulsrEnv
    learning_rate=1e-3,
    buffer_size=50000, # replaces SequentialMemory
    learning_starts=10, # replaces nb_steps_warmup
    target_update_interval=100, # similar to target_model_update
    verbose=1
)

# Train the agent
model.learn(total_timesteps=50000)

# Save model
# model.save("dqn_pulsr")

# Reload model if needed
# model = DQN.load("dqn_pulsr", env=env)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# C:\Users\user\anaconda3\Lib\site-packages\stable_baselines3\common\vec_env\patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 239      |
# |    ep_rew_mean      | 0        |
# |    exploration_rate | 0.818    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 669      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 956      |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00758  |
# |    n_updates        | 236      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 239      |
# |    ep_rew_mean      | 350      |
# |    exploration_rate | 0.637    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 564      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 1912     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 5.95     |
# |    n_updates        | 475      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 239      |
# |    ep_rew_mean      | 1.18e+03 |
# |    exploration_rate | 0.455    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 533      |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 2868     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 2.79     |
# |    n_updates        | 714      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 239      |
# |    ep_rew_mean      | 1.39e+03 |
# |    exploration_rate | 0.273    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 482      |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 3824     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 40.7     |
# |    n_updates        | 953      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 239      |
# |    ep_rew_mean      | 1.74e+03 |
# |    exploration_rate | 0.0918   |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 470      |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 4780     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 6.95     |
# |    n_updates        | 1192     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 239      |
# |    ep_rew_mean      | 1.87e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 458      |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 5736     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 13.3     |
# |    n_updates        | 1431     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 239      |
# |    ep_rew_mean      | 1.7e+03  |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 470      |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 6692     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 8.63     |
# |    n_updates        | 1670     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 239      |
# |    ep_rew_mean      | 1.59e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 476      |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 7648     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 11.9     |
# |    n_updates        | 1909     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 239      |
# |    ep_rew_mean      | 1.51e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 478      |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 8604     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 16.5     |
# |    n_updates        | 2148     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 239      |
# |    ep_rew_mean      | 1.56e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 470      |
# |    time_elapsed     | 20       |
# |    total_timesteps  | 9560     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 25.9     |
# |    n_updates        | 2387     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 239      |
# |    ep_rew_mean      | 1.51e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 466      |
# |    time_elapsed     | 22       |
# |    total_timesteps  | 10516    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 11.2     |
# |    n_updates        | 2626     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 239      |
# |    ep_rew_mean      | 1.48e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 465      |
# |    time_elapsed     | 24       |
# |    total_timesteps  | 11472    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 346      |
# |    n_updates        | 2865     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 239      |
# |    ep_rew_mean      | 1.52e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 460      |
# |    time_elapsed     | 27       |
# |    total_timesteps  | 12428    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 29.1     |
# |    n_updates        | 3104     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 239      |
# |    ep_rew_mean      | 1.54e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 458      |
# |    time_elapsed     | 29       |
# |    total_timesteps  | 13384    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 47.4     |
# |    n_updates        | 3343     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 239      |
# |    ep_rew_mean      | 1.55e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 459      |
# |    time_elapsed     | 31       |
# |    total_timesteps  | 14340    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 32       |
# |    n_updates        | 3582     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 239      |
# |    ep_rew_mean      | 1.51e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 463      |
# |    time_elapsed     | 33       |
# |    total_timesteps  | 15296    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 41.9     |
# |    n_updates        | 3821     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 239      |
# |    ep_rew_mean      | 1.49e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 458      |
# |    time_elapsed     | 35       |
# |    total_timesteps  | 16252    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 55.2     |
# |    n_updates        | 4060     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 239      |
# |    ep_rew_mean      | 1.8e+03  |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 450      |
# |    time_elapsed     | 38       |
# |    total_timesteps  | 17208    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 80.5     |
# |    n_updates        | 4299     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 239      |
# |    ep_rew_mean      | 2e+03    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 446      |
# |    time_elapsed     | 40       |
# |    total_timesteps  | 18164    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 150      |
# |    n_updates        | 4538     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 239      |
# |    ep_rew_mean      | 2.24e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 445      |
# |    time_elapsed     | 42       |
# |    total_timesteps  | 19120    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 15.4     |
# |    n_updates        | 4777     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 239      |
# |    ep_rew_mean      | 2.46e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 445      |
# |    time_elapsed     | 45       |
# |    total_timesteps  | 20076    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 31.5     |
# |    n_updates        | 5016     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 239      |
# |    ep_rew_mean      | 2.66e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 449      |
# |    time_elapsed     | 46       |
# |    total_timesteps  | 21032    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 137      |
# |    n_updates        | 5255     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 239      |
# |    ep_rew_mean      | 2.83e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 451      |
# |    time_elapsed     | 48       |
# |    total_timesteps  | 21988    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 115      |
# |    n_updates        | 5494     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 239      |
# |    ep_rew_mean      | 3e+03    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 451      |
# |    time_elapsed     | 50       |
# |    total_timesteps  | 22944    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 25.7     |
# |    n_updates        | 5733     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 239      |
# |    ep_rew_mean      | 3.15e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 447      |
# |    time_elapsed     | 53       |
# |    total_timesteps  | 23900    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 59.2     |
# |    n_updates        | 5972     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 239      |
# |    ep_rew_mean      | 3.42e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 443      |
# |    time_elapsed     | 56       |
# |    total_timesteps  | 24856    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 551      |
# |    n_updates        | 6211     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 239      |
# |    ep_rew_mean      | 3.67e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 439      |
# |    time_elapsed     | 58       |
# |    total_timesteps  | 25812    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 35.4     |
# |    n_updates        | 6450     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 239      |
# |    ep_rew_mean      | 3.83e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 438      |
# |    time_elapsed     | 61       |
# |    total_timesteps  | 26768    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 195      |
# |    n_updates        | 6689     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 239      |
# |    ep_rew_mean      | 4.02e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 441      |
# |    time_elapsed     | 62       |
# |    total_timesteps  | 27724    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 35.2     |
# |    n_updates        | 6928     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 239      |
# |    ep_rew_mean      | 4.19e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 443      |
# |    time_elapsed     | 64       |
# |    total_timesteps  | 28680    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 91.6     |
# |    n_updates        | 7167     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 239      |
# |    ep_rew_mean      | 4.4e+03  |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 442      |
# |    time_elapsed     | 67       |
# |    total_timesteps  | 29636    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 116      |
# |    n_updates        | 7406     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 239      |
# |    ep_rew_mean      | 4.71e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 440      |
# |    time_elapsed     | 69       |
# |    total_timesteps  | 30592    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 583      |
# |    n_updates        | 7645     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 239      |
# |    ep_rew_mean      | 5.02e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 443      |
# |    time_elapsed     | 71       |
# |    total_timesteps  | 31548    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 41.1     |
# |    n_updates        | 7884     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 239      |
# |    ep_rew_mean      | 5.32e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 444      |
# |    time_elapsed     | 73       |
# |    total_timesteps  | 32504    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 57       |
# |    n_updates        | 8123     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 239      |
# |    ep_rew_mean      | 5.57e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 445      |
# |    time_elapsed     | 75       |
# |    total_timesteps  | 33460    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 45.8     |
# |    n_updates        | 8362     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 239      |
# |    ep_rew_mean      | 5.88e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 444      |
# |    time_elapsed     | 77       |
# |    total_timesteps  | 34416    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 134      |
# |    n_updates        | 8601     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 239      |
# |    ep_rew_mean      | 6.15e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 446      |
# |    time_elapsed     | 79       |
# |    total_timesteps  | 35372    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 70.5     |
# |    n_updates        | 8840     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 239      |
# |    ep_rew_mean      | 6.38e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 448      |
# |    time_elapsed     | 81       |
# |    total_timesteps  | 36328    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.56e+03 |
# |    n_updates        | 9079     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 239      |
# |    ep_rew_mean      | 6.64e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 447      |
# |    time_elapsed     | 83       |
# |    total_timesteps  | 37284    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 43.7     |
# |    n_updates        | 9318     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 239      |
# |    ep_rew_mean      | 6.91e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 445      |
# |    time_elapsed     | 85       |
# |    total_timesteps  | 38240    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 62.1     |
# |    n_updates        | 9557     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 239      |
# |    ep_rew_mean      | 7.18e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 443      |
# |    time_elapsed     | 88       |
# |    total_timesteps  | 39196    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 122      |
# |    n_updates        | 9796     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 239      |
# |    ep_rew_mean      | 7.45e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 441      |
# |    time_elapsed     | 91       |
# |    total_timesteps  | 40152    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 65.8     |
# |    n_updates        | 10035    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 239      |
# |    ep_rew_mean      | 7.49e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 439      |
# |    time_elapsed     | 93       |
# |    total_timesteps  | 41108    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 478      |
# |    n_updates        | 10274    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 239      |
# |    ep_rew_mean      | 7.53e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 440      |
# |    time_elapsed     | 95       |
# |    total_timesteps  | 42064    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 92.1     |
# |    n_updates        | 10513    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 239      |
# |    ep_rew_mean      | 7.48e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 442      |
# |    time_elapsed     | 97       |
# |    total_timesteps  | 43020    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 72.5     |
# |    n_updates        | 10752    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 239      |
# |    ep_rew_mean      | 7.49e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 442      |
# |    time_elapsed     | 99       |
# |    total_timesteps  | 43976    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 60       |
# |    n_updates        | 10991    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 239      |
# |    ep_rew_mean      | 7.51e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 441      |
# |    time_elapsed     | 101      |
# |    total_timesteps  | 44932    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 87.9     |
# |    n_updates        | 11230    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 239      |
# |    ep_rew_mean      | 7.54e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 440      |
# |    time_elapsed     | 104      |
# |    total_timesteps  | 45888    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 53       |
# |    n_updates        | 11469    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 239      |
# |    ep_rew_mean      | 7.56e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 439      |
# |    time_elapsed     | 106      |
# |    total_timesteps  | 46844    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 533      |
# |    n_updates        | 11708    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 239      |
# |    ep_rew_mean      | 7.57e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 438      |
# |    time_elapsed     | 108      |
# |    total_timesteps  | 47800    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 211      |
# |    n_updates        | 11947    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 239      |
# |    ep_rew_mean      | 7.56e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 439      |
# |    time_elapsed     | 110      |
# |    total_timesteps  | 48756    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 254      |
# |    n_updates        | 12186    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 239      |
# |    ep_rew_mean      | 7.58e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 439      |
# |    time_elapsed     | 113      |
# |    total_timesteps  | 49712    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 81       |
# |    n_updates        | 12425    |
# ----------------------------------

# %%
# !pip install shimmy
# Out:
# Collecting shimmy
#   Downloading Shimmy-2.0.0-py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: numpy>=1.18.0 in c:\users\user\anaconda3\lib\site-packages (from shimmy) (2.1.3)
# Requirement already satisfied: gymnasium>=1.0.0a1 in c:\users\user\anaconda3\lib\site-packages (from shimmy) (1.2.0)
# Requirement already satisfied: cloudpickle>=1.2.0 in c:\users\user\anaconda3\lib\site-packages (from gymnasium>=1.0.0a1->shimmy) (1.6.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in c:\users\user\anaconda3\lib\site-packages (from gymnasium>=1.0.0a1->shimmy) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in c:\users\user\anaconda3\lib\site-packages (from gymnasium>=1.0.0a1->shimmy) (0.0.4)
# Downloading Shimmy-2.0.0-py3-none-any.whl (30 kB)
# Installing collected packages: shimmy
# Successfully installed shimmy-2.0.0

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[74], line 1
# ----> 1 scores = dqn.test(env, nb_episodes=100, visualize=False)
#       2 print(np.mean(scores.history['episode_reward']))
#
# NameError: name 'dqn' is not defined
